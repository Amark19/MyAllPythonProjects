# %%
import pandas as p

# %%
df=p.read_csv("data.csv")

# %%
df.head()
# Out:
#    SYMBOL \n    OPEN \n    HIGH \n     LOW \n PREV. CLOSE \n     LTP \n  \
# 0   NIFTY 50  15,371.45  15,431.75  15,242.20      15,314.70  15,313.45
# 1  POWERGRID      213.4      229.9      213.3         212.45     225.75
# 2       ONGC      99.25     104.85      99.25          98.45     103.35
# 3  TATASTEEL     672.15      708.6      668.3         672.15     697.65
# 4   HINDALCO     293.55     307.35        293          291.4        302
#
#    CHNG \n  %CHNG \n  VOLUME \n(shares)                VALUE    52W H \n  \
# 0    -1.25     -0.01          648545320  3,65,49,69,20,467.76  15,431.75
# 1    13.30      6.26           45113050    10,14,50,22,684.00      229.9
# 2     4.90      4.98           76236798     7,86,83,99,921.58      107.9
# 3    25.50      3.79           33661838    23,53,43,37,419.32      731.5
# 4    10.60      3.64           27519511     8,33,53,84,686.79     307.35
#
#    52W L \n  365 D % CHNG \n 11-Feb-2020  30 D % CHNG \n 11-Jan-2021
# ...

# %%
df.dtypes
# Out:
# SYMBOL \n                       object
# OPEN \n                         object
# HIGH \n                         object
# LOW \n                          object
# PREV. CLOSE \n                  object
# LTP \n                          object
# CHNG \n                        float64
# %CHNG \n                       float64
# VOLUME \n(shares)                int64
# VALUE                           object
# 52W H \n                        object
# 52W L \n                        object
# 365 D % CHNG \n 11-Feb-2020    float64
# 30 D % CHNG \n 11-Jan-2021     float64
# dtype: object

# %%
df['SYMBOL \n'].astype('category')
# Out:
# 0       NIFTY 50
# 1      POWERGRID
# 2           ONGC
# 3      TATASTEEL
# 4       HINDALCO
# 5           NTPC
# 6      KOTAKBANK
# 7            IOC
# 8     ADANIPORTS
# 9      COALINDIA
# 10      RELIANCE
# 11        MARUTI
# 12        GRASIM
# 13            LT
# 14    ULTRACEMCO
# 15         TECHM
# 16      JSWSTEEL
# 17         CIPLA
# 18      HDFCBANK
# 19    BAJAJ-AUTO
# 20    INDUSINDBK
# 21     SUNPHARMA
# 22      SHREECEM
# 23           UPL
# 24      HDFCLIFE
# 25    HEROMOTOCO
# 26           M&M
# 27    BHARTIARTL
# 28           ITC
# 29       HCLTECH
# 30    ASIANPAINT
# 31          BPCL
# 32    BAJFINANCE
# 33          HDFC
# 34       DRREDDY
# 35         WIPRO
# 36       SBILIFE
# 37          GAIL
# 38         TITAN
# 39     BRITANNIA
# 40    BAJAJFINSV
# 41    HINDUNILVR
# 42           TCS
# 43      DIVISLAB
# 44          SBIN
# 45          INFY
# 46    TATAMOTORS
# 47     NESTLEIND
# 48     EICHERMOT
# 49      AXISBANK
# 50     ICICIBANK
# ...
